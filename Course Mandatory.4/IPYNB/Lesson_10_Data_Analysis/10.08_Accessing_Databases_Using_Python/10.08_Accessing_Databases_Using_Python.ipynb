# %% [markdown]
# ## __Accessing Databases Using Python__
#
# ## Step 1: Import the Dataset
#
# Let's first import our dataset, dump it into a database and then perform queries on it. We’ll be using sqlite3.

# %%
import sqlite3
import pandas as pd

# %%
df = pd.read_csv("HousePrices.csv")

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %% [markdown]
# __Observation__
#
# This is the head of the dataset.

# %% [markdown]
# ## Step 2: Create an SQLite3 Connection
#
# Before dumping it into the database, let's create a connection.

# %%
connection = sqlite3.connect('test.db')

# %%
df.to_sql('test',connection,if_exists='replace',index = False)

# %% [markdown]
# __Observation__
#
# The connection has been created inside a database.

# %% [markdown]
# ## Step 3: Read the Data Using a Cursor
#
# Let's execute a query to fetch data from the **test** table using a cursor.

# %%
cursor = connection.cursor()
query = "select * from test"
cursor.execute(query)

# %%
results = cursor.fetchall()

# %%
results[:2]
# Out:
# [('2014-05-02 00:00:00',
#   313000.0,
#   3.0,
#   1.5,
#   1340,
#   7912,
#   1.5,
#   0,
#   0,
#   3,
#   1340,
#   0,
#   1955,
#   2005,
#   '18810 Densmore Ave N',
#   'Shoreline',
#   'WA 98133',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   2384000.0,
#   5.0,
#   2.5,
#   3650,
#   9050,
#   2.0,
#   0,
#   4,
#   5,
#   3370,
#   280,
#   1921,
#   0,
#   '709 W Blaine St',
#   'Seattle',
#   'WA 98119',
#   'USA')]

# %% [markdown]
# __Observation__
#
# Thus, the first two rows were printed.

# %% [markdown]
# ## Step 4 Read the Data Using Pandas
#
# Let's read the data using pandas and the .read SQL method.

# %%
data = pd.read_sql(query,connection)

# %%
data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0         7912     1.5           0     0          3        1340
# 1         9050     2.0           0     4          5        3370
# 2        11947     1.0           0     0          4        1930
# 3         8030     1.0           0     0          4        1000
# 4        10500     1.0           0     0          4        1140
# ...        ...     ...         ...   ...        ...         ...
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated                    street  \
# 0                 0      1955          2005      18810 Densmore Ave N
# 1               280      1921             0           709 W Blaine St
# 2                 0      1966             0  26206-26214 143rd Ave SE
# 3              1000      1963             0           857 170th Pl NE
# 4               800      1976          1992         9105 170th Ave NE
# ...             ...       ...           ...                       ...
# 4595              0      1954          1979            501 N 143rd St
# 4596              0      1983          2009          14855 SE 10th Pl
# 4597              0      2009             0          759 Ilwaco Pl NE
# 4598           1020      1974             0         5148 S Creston St
# 4599              0      1990             0         18717 SE 258th St
#
#            city  statezip country
# 0     Shoreline  WA 98133     USA
# 1       Seattle  WA 98119     USA
# 2          Kent  WA 98042     USA
# 3      Bellevue  WA 98008     USA
# 4       Redmond  WA 98052     USA
# ...         ...       ...     ...
# 4595    Seattle  WA 98133     USA
# 4596   Bellevue  WA 98007     USA
# 4597     Renton  WA 98059     USA
# 4598    Seattle  WA 98178     USA
# 4599  Covington  WA 98042     USA
#
# [4600 rows x 18 columns]

# %% [markdown]
# __Observation__
#
# The data here is the entire dataset.

# %% [markdown]
# ## Step 7: Filter the Data Based on a Particular Keyword
#
# Let's start with a query using the **where** keyword.

# %%
query = 'select * from test where city = "Seattle"'
data = pd.read_sql(query,connection)

# %%
data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 1     2014-05-02 00:00:00  4.900000e+05       2.0       1.00          880
# 2     2014-05-02 00:00:00  6.400000e+05       4.0       2.00         1520
# 3     2014-05-02 00:00:00  1.400000e+06       4.0       2.50         2920
# 4     2014-05-02 00:00:00  3.650000e+05       3.0       1.00         1090
# ...                   ...           ...       ...        ...          ...
# 1568  2014-07-07 00:00:00  4.060625e+05       2.0       1.00         1290
# 1569  2014-07-07 00:00:00  4.868950e+05       3.0       1.00         1890
# 1570  2014-07-08 00:00:00  3.961667e+05       3.0       1.75         1880
# 1571  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 1572  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0         9050     2.0           0     4          5        3370
# 1         6380     1.0           0     0          3         880
# 2         6200     1.5           0     0          3        1520
# 3         4000     1.5           0     0          5        1910
# 4         6435     1.0           0     0          4        1090
# ...        ...     ...         ...   ...        ...         ...
# 1568      4650     1.0           0     0          4        1290
# 1569      3330     1.5           0     0          4        1390
# 1570      5752     1.0           0     0          4         940
# 1571      6360     1.0           0     0          4        1510
# 1572      6630     1.0           0     0          3        1070
#
#       sqft_basement  yr_built  yr_renovated                 street     city  \
# 0               280      1921             0        709 W Blaine St  Seattle
# 1                 0      1938          1994         522 NE 88th St  Seattle
# 2                 0      1945          2010       6811 55th Ave NE  Seattle
# 3              1010      1909          1988  3838-4098 44th Ave NE  Seattle
# 4                 0      1955          2009    2504 SW Portland Ct  Seattle
# ...             ...       ...           ...                    ...      ...
# 1568              0      1906          1990         312 NE 81st St  Seattle
# 1569            500      1901             0      4324 Dayton Ave N  Seattle
# 1570            940      1945             0     3529 SW Webster St  Seattle
# 1571              0      1954          1979         501 N 143rd St  Seattle
# 1572           1020      1974             0      5148 S Creston St  Seattle
#
#       statezip country
# 0     WA 98119     USA
# 1     WA 98115     USA
# 2     WA 98115     USA
# 3     WA 98105     USA
# 4     WA 98106     USA
# ...        ...     ...
# 1568  WA 98115     USA
# 1569  WA 98103     USA
# 1570  WA 98126     USA
# 1571  WA 98133     USA
# 1572  WA 98178     USA
#
# [1573 rows x 18 columns]

# %% [markdown]
# __Observation__
#
# This is the data that contains data from **Seattle** only.

# %% [markdown]
# ### __Note:__
#
# If you are trying to access other databases, Python offers various libraries. For example, PI Mongo can be used to access MongoDB.
